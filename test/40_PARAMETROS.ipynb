# %% [markdown]
# <br>
#
# # Introdução

# %%
import os
import re
import sys
import pprint
import pandas as pd
from scipy.stats import gmean
from dateutil.relativedelta import relativedelta

# %%
from paths import *

# %%
# Parameters
#cod_ibge = '3548906' # São Carlos
#cod_ibge = '3526902' # Limeira
#cod_ibge = '3505203' # Barrrrrr
cod_ibge = '3501608' # Americana

# %% [markdown]
# <br>
#
# # Tabelas do Controle

# %% [markdown]
# <br>
#
# ## Parâmetros Básicos

# %%
# Read Table
df_bruta = pd.read_excel(
    os.path.join(output_path, str(cod_ibge), 'dados brutos', 'controle', 'controle_mensal_parametros_basicos.xlsx')
)

# %%
# Filtra Apenas SAAs
df = df_bruta.loc[df_bruta['Tipo Da Forma De Abastecimento'] == 'SAA'].copy()

# %%
# Filtra Apenas Último Ano
df = df[df['Ano De Referência'] == max(df['Ano De Referência'])].copy()

# %%
set(df['Parâmetro'])
# Out:
# {'Bactérias Heterotróficas (UFC/mL)',
#  'Cloro Residual Livre (mg/L)',
#  'Coliformes totais',
#  'Cor (uH)',
#  'Escherichia coli',
#  'Fluoreto (mg/L)',
#  'Turbidez (uT)',
#  'pH'}

# %% [markdown]
# <br>
#
# ## Demais Parâmetros

# %%
# Read Table
df_bruta = pd.read_excel(
    os.path.join(output_path, str(cod_ibge), 'dados brutos', 'controle', 'controle_mensal_demais_parametros.xlsx')
)

# %%
# Filtra Apenas SAAs
df = df_bruta.loc[df_bruta['Tipo Da Forma De Abastecimento'] == 'SAA'].copy()

# %%
# Filtra Apenas Último Ano
df = df[df['Ano De Referência'] == max(df['Ano De Referência'])].copy()

# %%
set(df['Parâmetro'])
# Out:
# {'Cianobactérias',
#  'Clorofila-a',
#  'Cryptosporidium',
#  'Escherichia coli',
#  'Giardia',
#  'Vírus'}

# %% [markdown]
# <br>
#
# ## Fora do Padrão

# %%
# Read Table
df_bruta = pd.read_excel(
    os.path.join(output_path, str(cod_ibge), 'dados brutos', 'controle', 'controle_mensal_amostras_fora_padrao.xlsx')
)

# %%
# Filtra Apenas SAAs
df = df_bruta.loc[df_bruta['Tipo Da Forma De Abastecimento'] == 'SAA'].copy()

# %%
# Filtra Apenas Último Ano
df = df[df['Ano De Referência'] == max(df['Ano De Referência'])].copy()

# %%
set(df['Parâmetro'])
# Out:
# {'Cloro Residual Livre (mg/L)', 'Coliformes totais'}

# %% [markdown]
# <br>
#
# ## Controle Semestral

# %%
# Read Table
df_bruta = pd.read_excel(
    os.path.join(output_path, str(cod_ibge), 'dados brutos', 'controle', 'controle_semestral.xlsx')
)

# %%
# Filtra Apenas SAAs
df = df_bruta.loc[df_bruta['Tipo Da Forma De Abastecimento'] == 'SAA']

# %%
#df.info()
#list(df.columns)

# %%
# Filtra Apenas Último Ano
df = df[df['Ano De Referência'] == max(df['Ano De Referência'])].copy()

# %%
set(df['Parâmetro'])
# Out:
# {'1,1 Dicloroeteno - VMP:30,0 µg/L',
#  '1,2 Diclorobenzeno VMP - 0,01 mg/L',
#  '1,2 Dicloroetano - VMP:10,0 µg/L',
#  '1,2 Dicloroeteno (cis + trans) - VMP:50,0 µg/L',
#  '1,4 Diclorobenzeno VMP - 0,03 mg/L',
#  '2, 4, 6 Triclorofenol - VMP: 0,2 mg/L',
#  '2,4 D + 2,4,5 T - VMP: 30,0 µg/L',
#  'Acrilamida - VMP:0,5 µg/L',
#  'Alaclor - VMP: 20,0 µg/L',
#  'Aldicarbe + Aldicarbesulfona + Aldicarbesulfóxido',
#  'Aldrin + Dieldrin - VMP: 0,03 µg/L',
#  'Alumínio VMP - 0,2 mg/L',
#  'Amônia (como NH3) VMP - 1,5 mg/L',
#  'Antimônio - VMP:0,005 mg/L',
#  'Arsênio - VMP:0,01 mg/L',
#  'Atividade alfa total - VMP: 0,5 Bq/L',
#  'Atividade beta total - VMP: 1,0 Bq/L',
#  'Atrazina - VMP: 2,0 µg/L',
#  'Benzeno - VMP:5,0 µg/L',
#  'Benzo[a]pireno - VMP:0,7 µg/L',
#  'Bário - VMP:0,7 mg/L',
#  'Carbendazim + benomil - VMP: 120,0 µg/L',
#  'Carbofurano - VMP: 7,0 µg/L',
#  'Chumbo - VMP:0,01 mg/L',
#  'Cianeto - VMP:0,07 mg/L',
#  'Clordano - VMP: 0,2 µg/L',
#  'Cloreto VMP - 250,0 mg/L',
#  'Cloreto de Vinila - VMP:2,0 µg/L',
#  'Clorpirifós + clorpirifós-oxon - VMP: 30,0 µg/L',
#  'Cobre - VMP:2,0 mg/L',
#  'Cor Aparente VMP - 15,0 uH',
#  'Cromo - VMP:0,05 mg/L',
#  'Cádmio - VMP:0,005 mg/L',
#  'DDT + DDD + DDE - VMP: 1,0 µg/L',
#  'Di (2-etilhexil) ftalato - VMP:8,0 µg/L',
#  'Diclorometano - VMP:20,0 µg/L',
#  'Diuron - VMP: 90,0 µg/L',
#  'Dureza total VMP - 500,0 mg/L',
#  'Endossulfan (a, ß e sais) - VMP: 20,0 µg/L',
#  'Endrin - VMP: 0,6 µg/L',
#  'Estireno - VMP:20,0 µg/L',
#  'Etilbenzeno VMP - 0,2 mg/L',
#  'Ferro VMP - 0,3 mg/L',
#  'Glifosato + AMPA - VMP: 500,0 µg/L',
#  'Gosto e odor VMP - 6,0 Intensidade',
#  'Lindano (gama HCH) - VMP: 2,0 µg/L',
#  'Mancozebe - VMP: 180,0 µg/L',
#  'Manganês VMP - 0,1 mg/L',
#  'Mercúrio - VMP:0,001 mg/L',
#  'Metamidofós - VMP: 12,0 µg/L',
#  'Metolacloro - VMP: 10,0 µg/L',
#  'Molinato - VMP: 6,0 µg/L',
#  'Monoclorobenzeno VMP - 0,12 mg/L',
#  'Nitrato (como N) - VMP:10,0 mg/L',
#  'Nitrito (como N) - VMP:1,0 mg/L',
#  'Níquel - VMP:0,07 mg/L',
#  'Parationa Metílica - VMP: 9,0 µg/L',
#  'Pendimentalina - VMP: 20,0 µg/L',
#  'Pentaclorofenol - VMP:9,0 µg/L',
#  'Permetrina - VMP: 20,0 µg/L',
#  'Profenofós - VMP: 60,0 µg/L',
#  'Selênio - VMP:0,01 mg/L',
#  'Simazina - VMP: 2,0 µg/L',
#  'Sulfato VMP - 250,0 mg/L',
#  'Sulfeto de hidrogênio VMP - 0,1 mg/L',
#  'Surfactantes (como LAS) VMP - 0,5 mg/L',
#  'Sódio VMP - 200,0 mg/L',
#  'Sólidos dissolvidos totais VMP - 1000,0 mg/L',
#  'Tebuconazol - VMP: 180,0 µg/L',
#  'Terbufós - VMP: 1,2 µg/L',
#  'Tetracloreto de Carbono - VMP:4,0 µg/L',
#  'Tetracloroeteno - VMP:40,0 µg/L',
#  'Tolueno VMP - 0,17 mg/L',
#  'Triclorobenzenos - VMP:20,0 µg/L',
#  'Tricloroeteno - VMP:20,0 µg/L',
#  'Trifluralina - VMP: 20,0 µg/L',
#  'Trihalometanos Total - VMP: 0,1 mg/L',
#  'Urânio - VMP:0,03 mg/L',
#  'Xilenos VMP - 0,3 mg/L',
#  'Zinco VMP - 5,0 mg/L',
#  'Ácidos haloacéticos total - VMP: 0,08 mg/L'}

# %% [markdown]
# <br>
#
# # Tabelas da Vigilância

# %% [markdown]
# <br>
#
# ## Parâmetros Básicos

# %%
# Read Table
df_bruta = pd.read_excel(
    os.path.join(output_path, str(cod_ibge), 'dados brutos', 'vigilancia', 'vigilancia_parametros_basicos.xlsx')
)

# %%
# Filtra Apenas SAAs
df = df_bruta.loc[df_bruta['Tipo Da Forma De Abastecimento'] == 'SAA'].copy()

# %%
# Filtra Apenas Último Ano
#df = df[df['Ano'] == max(df['Ano'])].copy()

# %% [markdown]
# - 'Cloro residual livre (mg/L)',
# - 'Escherichia coli',
# - 'Fluoreto (mg/L)',
# - 'Turbidez (uT)',
# - 'Cor (uH)',
# - 'Coliformes totais',
#
# - 'pH'

# %%
set(df['Parâmetro (Parâmetros Básicos)'])
# Out:
# {'Cloro residual livre (mg/L)',
#  'Coliformes totais',
#  'Cor (uH)',
#  'Escherichia coli',
#  'Fluoreto (mg/L)',
#  'Turbidez (uT)',
#  'pH'}

# %%
df = df[df['Parâmetro (Parâmetros Básicos)'].str.contains('Coliformes')]

# %%
df.reset_index(drop=True, inplace=True)
df.dropna(how='all', inplace=True)

# %%
set(df['Resultado'])
# Out:
# {'AUSENTE', 'PRESENTE'}

# %%
df['Resultado'] = df['Resultado'].map({'AUSENTE': 0, 'PRESENTE': 1})

# %%
# Ajusta Resultados
df['Resultado'] = df['Resultado'].astype(str).str.replace(',', '.')
df['Resultado'] = pd.to_numeric(df['Resultado'])

# %%
# Adjust Dates
df['Data Da Coleta'] = pd.to_datetime(df['Data Da Coleta'])

# %%
df.dtypes
# Out:
# Região Geográfica                            object
# Regional De Saúde                            object
# Município                                    object
# Número Da Amostra                            object
# Motivo Da Coleta                             object
# Tipo Da Forma De Abastecimento               object
# Código Forma De Abastecimento                object
# Nome Da Forma De Abastecimento               object
# Tipo Da Instituição                          object
# Sigla Da Instituição                        float64
# Nome Da Instituição                          object
# Cnpj Da Instituição                         float64
# Nome Do Escritório Regional/Local           float64
# Cnpj Do Escritório Regional/Local           float64
# Nome Da Eta/Uta                             float64
# Ano                                           int64
# Mês                                           int64
# Data Da Coleta                       datetime64[ns]
# Data Do Laudo                                object
# Data De Registro No Sisagua                  object
# Procedência Da Coleta                        object
# Ponto De Coleta                              object
# Descrição Do Local                           object
# Zona                                         object
# Categoria Área                               object
# Área                                         object
# Tipo Do Local                                object
# Local                                        object
# Latitude                                    float64
# Longitude                                   float64
# Parâmetro (Parâmetros Básicos)               object
# Análise Realizada                            object
# Resultado                                     int64
# Providência                                  object
# Uf                                           object
# Código Ibge                                   int64
# dtype: object

# %%
df.tail()
# Out:
#      Região Geográfica    Regional De Saúde  Município Número Da Amostra  \
# 6297           SUDESTE  GVS XVII - CAMPINAS  AMERICANA      211741000186
# 6298           SUDESTE  GVS XVII - CAMPINAS  AMERICANA      211741000149
# 6331           SUDESTE  GVS XVII - CAMPINAS  AMERICANA      221741000005
# 6333           SUDESTE  GVS XVII - CAMPINAS  AMERICANA      221741000007
# 6337           SUDESTE  GVS XVII - CAMPINAS  AMERICANA      221741000006
#
#      Motivo Da Coleta Tipo Da Forma De Abastecimento  \
# 6297           Rotina                            SAA
# 6298           Rotina                            SAA
# 6331           Rotina                            SAA
# 6333           Rotina                            SAA
# 6337           Rotina                            SAA
#
#      Código Forma De Abastecimento Nome Da Forma De Abastecimento  \
# 6297                 S350160000001                            ETA
# 6298                 S350160000001                            ETA
# 6331                 S350160000001                            ETA
# 6333                 S350160000001                            ETA
# 6337                 S350160000001                            ETA
#
#              Tipo Da Instituição  Sigla Da Instituição  ... Tipo Do Local  \
# 6297  Serviço Municipal e outros                   NaN  ...           NaN
# 6298  Serviço Municipal e outros                   NaN  ...           NaN
# 6331  Serviço Municipal e outros                   NaN  ...           NaN
# 6333  Serviço Municipal e outros                   NaN  ...           NaN
# 6337  Serviço Municipal e outros                   NaN  ...           NaN
#
#       Local  Latitude  Longitude  Parâmetro (Parâmetros Básicos)  \
# 6297    NaN       NaN        NaN                Escherichia coli
# 6298    NaN       NaN        NaN                Escherichia coli
# 6331    NaN       NaN        NaN                Escherichia coli
# 6333    NaN       NaN        NaN                Escherichia coli
# 6337    NaN       NaN        NaN                Escherichia coli
#
#       Análise Realizada  Resultado Providência  Uf Código Ibge
# 6297                NaN          0         NaN  SP      350160
# 6298                NaN          0         NaN  SP      350160
# 6331                NaN          0         NaN  SP      350160
# 6333                NaN          0         NaN  SP      350160
# 6337                NaN          0         NaN  SP      350160
#
# [5 rows x 36 columns]

# %%
#df.iloc[616]
print(len(df))
df.loc[600:616]
# Out:
# 616
#     Região Geográfica Regional De Saúde Município Número Da Amostra  \
# 600           SUDESTE    GVS XV - BAURU    BARIRI      211523000002
# 601           SUDESTE    GVS XV - BAURU    BARIRI      211523000004
# 602           SUDESTE    GVS XV - BAURU    BARIRI      211523000040
# 603           SUDESTE    GVS XV - BAURU    BARIRI      211523000010
# 604           SUDESTE    GVS XV - BAURU    BARIRI      211523000110
# 605           SUDESTE    GVS XV - BAURU    BARIRI      211523000077
# 606           SUDESTE    GVS XV - BAURU    BARIRI      211523000106
# 607           SUDESTE    GVS XV - BAURU    BARIRI      211523000043
# 608           SUDESTE    GVS XV - BAURU    BARIRI      211523000041
# 609           SUDESTE    GVS XV - BAURU    BARIRI      211523000100
# 610           SUDESTE    GVS XV - BAURU    BARIRI      211523000027
# 611           SUDESTE    GVS XV - BAURU    BARIRI      211523000057
# 612           SUDESTE    GVS XV - BAURU    BARIRI      211523000066
# 613           SUDESTE    GVS XV - BAURU    BARIRI      211523000075
# 614           SUDESTE    GVS XV - BAURU    BARIRI      211523000113
# 615           SUDESTE    GVS XV - BAURU    BARIRI      211523000064
#
#     Motivo Da Coleta Tipo Da Forma De Abastecimento  \
# 600           Rotina                            SAA
# 601           Rotina                            SAA
# 602           Rotina                            SAA
# 603           Rotina                            SAA
# 604           Rotina                            SAA
# 605           Rotina                            SAA
# 606           Rotina                            SAA
# 607           Rotina                            SAA
# 608           Rotina                            SAA
# 609           Rotina                            SAA
# 610           Rotina                            SAA
# 611           Rotina                            SAA
# 612           Rotina                            SAA
# 613           Rotina                            SAA
# 614           Rotina                            SAA
# 615           Rotina                            SAA
#
#     Código Forma De Abastecimento        Nome Da Forma De Abastecimento  \
# 600                 S350520000001  ESTACAO DE TRATAMENTO DE AGUA BARIRI
# 601                 S350520000004                             POCO SETE
# 602                 S350520000001  ESTACAO DE TRATAMENTO DE AGUA BARIRI
# 603                 S350520000001  ESTACAO DE TRATAMENTO DE AGUA BARIRI
# 604                 S350520000001  ESTACAO DE TRATAMENTO DE AGUA BARIRI
# 605                 S350520000002                   POCO TIRO DE GUERRA
# 606                 S350520000002                   POCO TIRO DE GUERRA
# 607                 S350520000004                             POCO SETE
# 608                 S350520000001  ESTACAO DE TRATAMENTO DE AGUA BARIRI
# 609                 S350520000003                     POCO SANTA HELENA
# 610                 S350520000003                     POCO SANTA HELENA
# 611                 S350520000003                     POCO SANTA HELENA
# 612                 S350520000002                   POCO TIRO DE GUERRA
# 613                 S350520000003                     POCO SANTA HELENA
# 614                 S350520000003                     POCO SANTA HELENA
# 615                 S350520000003                     POCO SANTA HELENA
#
#             Tipo Da Instituição  Sigla Da Instituição  ... Tipo Do Local  \
# 600  Serviço Municipal e outros                   NaN  ...           NaN
# 601  Serviço Municipal e outros                   NaN  ...           NaN
# 602  Serviço Municipal e outros                   NaN  ...           NaN
# 603  Serviço Municipal e outros                   NaN  ...           NaN
# 604  Serviço Municipal e outros                   NaN  ...           NaN
# 605  Serviço Municipal e outros                   NaN  ...           NaN
# 606  Serviço Municipal e outros                   NaN  ...           NaN
# 607  Serviço Municipal e outros                   NaN  ...           NaN
# 608  Serviço Municipal e outros                   NaN  ...           NaN
# 609  Serviço Municipal e outros                   NaN  ...           NaN
# 610  Serviço Municipal e outros                   NaN  ...           NaN
# 611  Serviço Municipal e outros                   NaN  ...           NaN
# 612  Serviço Municipal e outros                   NaN  ...           NaN
# 613  Serviço Municipal e outros                   NaN  ...           NaN
# 614  Serviço Municipal e outros                   NaN  ...           NaN
# 615  Serviço Municipal e outros                   NaN  ...           NaN
#
#      Local  Latitude  Longitude  Parâmetro (Parâmetros Básicos)  \
# 600    NaN       NaN        NaN     Cloro residual livre (mg/L)
# 601    NaN       NaN        NaN     Cloro residual livre (mg/L)
# 602    NaN       NaN        NaN     Cloro residual livre (mg/L)
# 603    NaN       NaN        NaN     Cloro residual livre (mg/L)
# 604    NaN       NaN        NaN     Cloro residual livre (mg/L)
# 605    NaN       NaN        NaN     Cloro residual livre (mg/L)
# 606    NaN       NaN        NaN     Cloro residual livre (mg/L)
# 607    NaN       NaN        NaN     Cloro residual livre (mg/L)
# 608    NaN       NaN        NaN     Cloro residual livre (mg/L)
# 609    NaN       NaN        NaN     Cloro residual livre (mg/L)
# 610    NaN       NaN        NaN     Cloro residual livre (mg/L)
# 611    NaN       NaN        NaN     Cloro residual livre (mg/L)
# 612    NaN       NaN        NaN     Cloro residual livre (mg/L)
# 613    NaN       NaN        NaN     Cloro residual livre (mg/L)
# 614    NaN       NaN        NaN     Cloro residual livre (mg/L)
# 615    NaN       NaN        NaN     Cloro residual livre (mg/L)
#
#      Análise Realizada  Resultado            Providência  Uf Código Ibge
# 600           EM_CAMPO       1.52                    NaN  SP      350520
# 601           EM_CAMPO       1.24                    NaN  SP      350520
# 602           EM_CAMPO       1.00                    NaN  SP      350520
# 603           EM_CAMPO       1.22                    NaN  SP      350520
# 604           EM_CAMPO       1.69                    NaN  SP      350520
# 605           EM_CAMPO       1.43                    NaN  SP      350520
# 606           EM_CAMPO       0.49                    NaN  SP      350520
# 607           EM_CAMPO       1.46                    NaN  SP      350520
# 608           EM_CAMPO       2.33                    NaN  SP      350520
# 609           EM_CAMPO       0.10  Enviado oficio ao SAA  SP      350520
# 610           EM_CAMPO       1.78                    NaN  SP      350520
# 611           EM_CAMPO       2.08                    NaN  SP      350520
# 612           EM_CAMPO       1.88                    NaN  SP      350520
# 613           EM_CAMPO       1.39                    NaN  SP      350520
# 614           EM_CAMPO       1.00                    NaN  SP      350520
# 615           EM_CAMPO       0.99                    NaN  SP      350520
#
# [16 rows x 36 columns]

# %% [markdown]
# <br>
#
# ## Demais Parâmetros

# %%
# Read Table
df_bruta = pd.read_excel(
    os.path.join(output_path, str(cod_ibge), 'dados brutos', 'vigilancia', 'vigilancia_demais_parametros.xlsx')
)

df_bruta.columns
# Out:
# Index(['Região Geográfica', 'Regional De Saúde', 'Município',
#        'Número Da Amostra', 'Motivo Da Coleta',
#        'Tipo Da Forma De Abastecimento', 'Código Forma De Abastecimento',
#        'Nome Da Forma De Abastecimento', 'Tipo Da Instituição',
#        'Sigla Da Instituição', 'Nome Da Instituição', 'Cnpj Da Instituição',
#        'Nome Do Escritório Regional/Local',
#        'Cnpj Do Escritório Regional/Local', 'Nome Da Eta/Uta', 'Ano', 'Mês',
#        'Data Da Coleta', 'Data Do Laudo', 'Data De Registro No Sisagua',
#        'Procedência Da Coleta', 'Ponto De Coleta', 'Descrição Do Local',
#        'Zona', 'Categoria Área', 'Área', 'Tipo Do Local', 'Local', 'Latitude',
#        'Longitude', 'Grupo De Parâmetros', 'Parâmetro (Demais Parâmetros)',
#        'Data Da Análise', 'Ld', 'Lq', 'Resultado', 'Uf', 'Código Ibge'],
#       dtype='object')

# %%
# Filtra Apenas SAAs
df = df_bruta.loc[df_bruta['Tipo Da Forma De Abastecimento'] == 'SAA'].copy()

# %%
# Filtra Apenas Último Ano
df = df[df['Ano'] == max(df['Ano'])].copy()

# %%
set(df['Parâmetro (Demais Parâmetros)'])
# Out:
# {'Cor Aparente - VMP: 15,0 mg/L', 'Ferro - VMP: 0,3 mg/L'}

# %% [markdown]
# <br>
#
# # Análises

# %% [markdown]
# # Lixos

# %%
#df = df[df['Parâmetro'] == 'Escherichia coli'].copy()
df = df[df['Parâmetro'].str.contains('Cloro')].copy()
df.head()
# Out:
# Empty DataFrame
# Columns: [Região Geográfica, Regional De Saúde, Município, Tipo Da Instituição, Sigla Da Instituição, Nome Da Instituição, Cnpj Da Instituição, Nome Do Escritório Regional/Local, Cnpj Do Escritório Regional/Local, Tipo Da Forma De Abastecimento, Código Forma De Abastecimento, Nome Da Forma De Abastecimento, Nome Da Eta / Uta, Ano De Referência, Semestre De Referência, Data De Registro, Data De Preenchimento Do Relatório Semestral, Data Da Coleta, Data Da Análise, Ponto De Monitoramento, Grupo De Parâmetros, Parâmetro, Ld, Lq, Resultado, Uf, Código Ibge]
# Index: []
#
# [0 rows x 27 columns]

# %%
set(df['Ponto De Monitoramento'])
# Out:
# set()

# %%
df = df[df['Ponto De Monitoramento'] == 'SAÍDA DO TRATAMENTO'].copy()
df.head()
# Out:
#        Região Geográfica    Regional De Saúde  Município Tipo Da Instituição  \
# 327619           SUDESTE  GVS XVII - CAMPINAS  AMERICANA               Local
# 327620           SUDESTE  GVS XVII - CAMPINAS  AMERICANA               Local
# 327621           SUDESTE  GVS XVII - CAMPINAS  AMERICANA               Local
# 327622           SUDESTE  GVS XVII - CAMPINAS  AMERICANA               Local
# 327623           SUDESTE  GVS XVII - CAMPINAS  AMERICANA               Local
#
#         Sigla Da Instituição            Nome Da Instituição  \
# 327619                   NaN  DEPARTAMENTO DE AGUA E ESGOTO
# 327620                   NaN  DEPARTAMENTO DE AGUA E ESGOTO
# 327621                   NaN  DEPARTAMENTO DE AGUA E ESGOTO
# 327622                   NaN  DEPARTAMENTO DE AGUA E ESGOTO
# 327623                   NaN  DEPARTAMENTO DE AGUA E ESGOTO
#
#         Cnpj Da Instituição  Nome Do Escritório Regional/Local  \
# 327619         4.675569e+13                                NaN
# 327620         4.675569e+13                                NaN
# 327621         4.675569e+13                                NaN
# 327622         4.675569e+13                                NaN
# 327623         4.675569e+13                                NaN
#
#         Cnpj Do Escritório Regional/Local Tipo Da Forma De Abastecimento  ...  \
# 327619                                NaN                            SAA  ...
# 327620                                NaN                            SAA  ...
# 327621                                NaN                            SAA  ...
# 327622                                NaN                            SAA  ...
# 327623                                NaN                            SAA  ...
#
#        Nome Da Eta / Uta Tipo De Filtração Ano De Referência  \
# 327619               ETA  FILTRAÇÃO RÁPIDA              2021
# 327620               ETA  FILTRAÇÃO RÁPIDA              2021
# 327621               ETA  FILTRAÇÃO RÁPIDA              2021
# 327622               ETA  FILTRAÇÃO RÁPIDA              2021
# 327623               ETA  FILTRAÇÃO RÁPIDA              2021
#
#        Mês De Referência  Ponto De Monitoramento                    Parâmetro  \
# 327619                11     SAÍDA DO TRATAMENTO  Cloro Residual Livre (mg/L)
# 327620                11     SAÍDA DO TRATAMENTO  Cloro Residual Livre (mg/L)
# 327621                11     SAÍDA DO TRATAMENTO  Cloro Residual Livre (mg/L)
# 327622                11     SAÍDA DO TRATAMENTO  Cloro Residual Livre (mg/L)
# 327623                11     SAÍDA DO TRATAMENTO  Cloro Residual Livre (mg/L)
#
#                                            Campo Valor  Uf Código Ibge
# 327619             Número de amostras analisadas  2436  SP      350160
# 327620                Número de dados > 5,0 mg/L     0  SP      350160
# 327621   Número de dados > 2,0 mg/L e <= 5,0mg/L   223  SP      350160
# 327622  Número de dados >= 0,2 mg/L e <= 2,0mg/L  2213  SP      350160
# 327623                Número de dados < 0,2 mg/L     0  SP      350160
#
# [5 rows x 22 columns]

# %%
df = df[['Ano De Referência', 'Mês De Referência', 'Campo', 'Valor']].copy()
df = df.sort_values(by=['Ano De Referência', 'Mês De Referência', 'Campo']).copy()
df.head()
# Out:
#         Ano De Referência  Mês De Referência  \
# 327648               2021                  1
# 327652               2021                  1
# 327650               2021                  1
# 327649               2021                  1
# 327651               2021                  1
#
#                                            Campo Valor
# 327648             Número de amostras analisadas  1483
# 327652                Número de dados < 0,2 mg/L     0
# 327650   Número de dados > 2,0 mg/L e <= 5,0mg/L     0
# 327649                Número de dados > 5,0 mg/L     0
# 327651  Número de dados >= 0,2 mg/L e <= 2,0mg/L  1483

# %% [markdown]
# Americana não tinha amostras no Ponto de captação....
#
# {'SAÍDA DO TRATAMENTO', 'SISTEMA DE DISTRIBUIÇÃO'}

# %%
df['Valor'] = df['Valor'].astype(str).str.replace(',','.')
df['Valor'] = df['Valor'].astype(float).fillna(0.0)
df.head()
# Out:
#         Ano De Referência  Mês De Referência  \
# 327648               2021                  1
# 327652               2021                  1
# 327650               2021                  1
# 327649               2021                  1
# 327651               2021                  1
#
#                                            Campo   Valor
# 327648             Número de amostras analisadas  1483.0
# 327652                Número de dados < 0,2 mg/L     0.0
# 327650   Número de dados > 2,0 mg/L e <= 5,0mg/L     0.0
# 327649                Número de dados > 5,0 mg/L     0.0
# 327651  Número de dados >= 0,2 mg/L e <= 2,0mg/L  1483.0

# %% [markdown]
# <br>
#
# Fazer gráfico multidimensional...
# Gráfico...
